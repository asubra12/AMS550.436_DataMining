# %% [markdown]
# <hr/>
#
# #Data Mining [EN.550.436]
# **Tamás Budavári** - budavari@jhu.edu <br/>
# **Assignment #2** - November 2, 2016
#
#
# <hr/>
#
# Anshul Subramanya
# asubra12
# 11/11/16

# %% [markdown]
# <h1><font color="darkblue">Assignment #2</font></h1>
#
# ####  Work alone!
# Please work on you own on these assignments!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Problem 1
#
# - Run the following code and comment it to show that you understand every character of it! (3 points)
# - Examine the `df` and `X` variables! What are they? (2 points)
# - What does the figure show? (1 points)
#
# Total: 6 points

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.read_csv('A2-Problem.csv',index_col='Pixel',dtype=np.uint8)  # Read in the csv file 'A2-Problem.csv'. Index_col assigns the column titled 'Pixel' as the column of row labels. Import all values as 8bit ints.
X = np.stack([df[k].reshape((40,40)) for k in df.columns], axis=2)  # Maps a list of 1600 pixels to their respective position in a 40x40 image matrix.

plt.figure(figsize=(12,3))  # Creates an empty figure
for i in range(X.shape[2]):  # For each of the R, G, B values
    plt.subplot(1,4,i+1)   # Create a subplot within the empty figure
    plt.imshow(X[:,:,i], interpolation='nearest', cmap=mpl.cm.gray)  # Plot a gray scale version of either the R, G, or B values
plt.subplot(1, 4, 4); plt.imshow(X, interpolation='nearest')  # Plot the original image

# %% [markdown]
# ### Questions
# 1. See Code
# 2. df is a data frame of 1600 values. The first value is the index of a particular pixel in the graph. This is numbered 1 through 1600, which is the total number of pixels in the image. X is a reformatting of df such that X[0,0,:] is the RGB values of the pixel in row 0, column 0 (in non-zero indexing, this is the first row, first column)
# 3. The figure shows a grayscale mapping of the R, G, and B components of the pixels in the image. The fourth image is a true-color image.

# %% [markdown]
# ### Problem 2
#
# - Run $k$-means clustering on the dataset (3 points)
# - How many components do you need? Why? (2 points)
# - Illustrate your results by using scatter plot(s) and/or images (2 points)
# - Can you improve the outcome by preprocessing or using a different algorithm? (2 points)
#
# Total: 9 points

# %%
from sklearn.cluster import KMeans
dfmat = df.as_matrix()

max_clusters = 15  # Attempt a total of 15 clusters
scores = np.zeros(max_clusters)  # Save all scores
for j in range(1,max_clusters+1):  # Attempt a different number of clusters
    nbrs = KMeans(n_clusters=j)  # Initialize a KMeans algorithm
    labels = nbrs.fit_predict(dfmat)  # Fit to data and predict own data
    score = nbrs.score(dfmat)
    scores[j-1] = score  # Save score

plt.figure()  # Create a figure
plt.plot(scores)  # Plot scores by cluster amount
plt.scatter(2, scores[2], marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')

print scores
# Out:
# [-3266296.43312499  -716699.92062431  -399532.8976402   -285567.34949655
#   -213162.06492994  -170330.5037787   -137705.32755035  -119122.52468093
#   -106952.60223638   -98555.51492708   -90931.26288714   -84257.60606371
#    -79107.16895328   -74230.02813914   -70008.29109576]

# %%
names = ['R', 'G', 'B']
for i in range(3):
    plt.figure()
    plt.hist(X[:,:,i])
    plt.title('Histogram of ' + names[i] + ' values from the Image')
    plt.xlabel(names[i] + ' Values')
    plt.ylabel('Frequency')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dfmat[:,0], dfmat[:,1], dfmat[:,2])

# %% [markdown]
# - Run $k$-means clustering on the dataset (3 points) Above
# - How many components do you need? Why? (2 points)
#   - We should require two clusters, and we can see this in four ways. First, the score of the clustering hardly increases from two clusters to more than two clusters. Second, in the histogram of R, G, and B values, there are always two notably higher spikes for each color. For the R values, this is between 70-95; for the G values, the spikes are between 135 and 160; for the B values, the spikes are between 25 and 50. Third, in the image itself, we can see that in either the grayscaled or full color images, there are two primary colors: gray and white (for gray scale) and green and white (for full image). Fourth, we can see that in the 3d scatter plot, there is a noticeable distinction in point density between points in the lower left end and upper right end of the points.
# - Illustrate your results by using scatter plot(s) and/or images (2 points) Above
# - Can you improve the outcome by preprocessing or using a different algorithm? (2 points)
#   - The outcome would be better if we could better pixellate the images. Currently, the resolution causes separations between dark and light to be blurred into a middle shade of gray which is difficult to classify into a particular mean.
